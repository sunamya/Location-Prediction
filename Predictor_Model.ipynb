# %% [markdown]
# # The Battle of Neighborhoods – Buildings Location Predictor

# %% [markdown]
# ##### Installing geopy and folium library and Importing all the necessary Libraries

# %%
#!conda install -c conda-forge geopy
#!conda install -c conda-forge folium=0.5.0
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Reading Data

# %%
data=pd.read_csv('IN.txt',delimiter='\t',names=['Country','Postal Code','Place Name','State','No1','County','no2','Province','No3','Latitude','Longitude','Accuracy'])
data.to_csv()
data.head()
# Out:
#   Country  Postal Code  Place Name                      State  No1   County  \
# 0      IN       744301     Lapathy  Andaman & Nicobar Islands    1  Nicobar
# 1      IN       744301      Kakana  Andaman & Nicobar Islands    1  Nicobar
# 2      IN       744301       Sawai  Andaman & Nicobar Islands    1  Nicobar
# 3      IN       744301  Carnicobar  Andaman & Nicobar Islands    1  Nicobar
# 4      IN       744301         Mus  Andaman & Nicobar Islands    1  Nicobar
#
#      no2    Province  No3  Latitude  Longitude  Accuracy
# 0  638.0  Carnicobar  NaN    9.1833    92.7667         3
# 1  638.0  Carnicobar  NaN    9.1167    92.8000         4
# 2  638.0  Carnicobar  NaN    7.5166    93.6031         4
# 3  638.0  Carnicobar  NaN    9.1833    92.7667         3
# 4  638.0  Carnicobar  NaN    9.2333    92.7833         4

# %% [markdown]
# ##### Deleting all the unnecessary Columns from the data

# %%
data.drop(['Country', 'No1','no2','No3','Accuracy'],inplace=True,axis=1)
data.head()
# Out:
#    Postal Code  Place Name                      State   County    Province  \
# 0       744301     Lapathy  Andaman & Nicobar Islands  Nicobar  Carnicobar
# 1       744301      Kakana  Andaman & Nicobar Islands  Nicobar  Carnicobar
# 2       744301       Sawai  Andaman & Nicobar Islands  Nicobar  Carnicobar
# 3       744301  Carnicobar  Andaman & Nicobar Islands  Nicobar  Carnicobar
# 4       744301         Mus  Andaman & Nicobar Islands  Nicobar  Carnicobar
#
#    Latitude  Longitude
# 0    9.1833    92.7667
# 1    9.1167    92.8000
# 2    7.5166    93.6031
# 3    9.1833    92.7667
# 4    9.2333    92.7833

# %% [markdown]
# ##### Merging all the duplicate data depending on Place Name

# %%
data= data.groupby('Postal Code').agg({'Place Name': ', '.join,'Province':'first', 'County': 'first', 'State':'first'}).reset_index()
data.head()
# Out:
#    Postal Code                                         Place Name  \
# 0       110001  New Delhi G.P.O., Parliament House, Connaught ...
# 1       110002  Civic Centre, Darya Ganj, Minto Road, Indrapra...
# 2       110003  Delhi High Court, Pandara Road, Delhi High Cou...
# 3       110004                                 Rashtrapati Bhawan
# 4       110005  Bank Street (Central Delhi), Karol Bagh, Anand...
#
#             Province         County  State
# 0          New Delhi      New Delhi  Delhi
# 1  New Delhi Central      New Delhi  Delhi
# 2          New Delhi  Central Delhi  Delhi
# 3          New Delhi  Central Delhi  Delhi
# 4          New Delhi  Central Delhi  Delhi

# %% [markdown]
# ##### Reading the Latitiude,Longitude Data

# %%
df=pd.read_csv('Data.txt',delimiter=',')
df.to_csv()
df.head()
# Out:
#    Postal Code               place_name admin_name1  latitude  longitude  \
# 0       110001          Connaught Place   New Delhi   28.6333    77.2167
# 1       110002               Darya Ganj   New Delhi   28.6333    77.2500
# 2       110003                  Aliganj   New Delhi   28.6500    77.2167
# 3       110004       Rashtrapati Bhawan   New Delhi   28.6500    77.2167
# 4       110005  Lower Camp Anand Parbat   New Delhi   28.6500    77.2000
#
#    accuracy
# 0       4.0
# 1       4.0
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# ##### Merging the two datasets

# %%
result=pd.merge(data,df,on='Postal Code')
result.head()
# Out:
#    Postal Code                                         Place Name  \
# 0       110001  New Delhi G.P.O., Parliament House, Connaught ...
# 1       110002  Civic Centre, Darya Ganj, Minto Road, Indrapra...
# 2       110003  Delhi High Court, Pandara Road, Delhi High Cou...
# 3       110004                                 Rashtrapati Bhawan
# 4       110005  Bank Street (Central Delhi), Karol Bagh, Anand...
#
#             Province         County  State               place_name  \
# 0          New Delhi      New Delhi  Delhi          Connaught Place
# 1  New Delhi Central      New Delhi  Delhi               Darya Ganj
# 2          New Delhi  Central Delhi  Delhi                  Aliganj
# 3          New Delhi  Central Delhi  Delhi       Rashtrapati Bhawan
# 4          New Delhi  Central Delhi  Delhi  Lower Camp Anand Parbat
#
#   admin_name1  latitude  longitude  accuracy
# 0   New Delhi   28.6333    77.2167       4.0
# 1   New Delhi   28.6333    77.2500       4.0
# 2   New Delhi   28.6500    77.2167       NaN
# 3   New Delhi   28.6500    77.2167       NaN
# 4   New Delhi   28.6500    77.2000       NaN

# %% [markdown]
# ##### Dropping the not required columns

# %%
result.drop(['admin_name1','accuracy'],inplace=True,axis=1)
result.head()
# Out:
#    Postal Code                                         Place Name  \
# 0       110001  New Delhi G.P.O., Parliament House, Connaught ...
# 1       110002  Civic Centre, Darya Ganj, Minto Road, Indrapra...
# 2       110003  Delhi High Court, Pandara Road, Delhi High Cou...
# 3       110004                                 Rashtrapati Bhawan
# 4       110005  Bank Street (Central Delhi), Karol Bagh, Anand...
#
#             Province         County  State               place_name  latitude  \
# 0          New Delhi      New Delhi  Delhi          Connaught Place   28.6333
# 1  New Delhi Central      New Delhi  Delhi               Darya Ganj   28.6333
# 2          New Delhi  Central Delhi  Delhi                  Aliganj   28.6500
# 3          New Delhi  Central Delhi  Delhi       Rashtrapati Bhawan   28.6500
# 4          New Delhi  Central Delhi  Delhi  Lower Camp Anand Parbat   28.6500
#
#    longitude
# 0    77.2167
# 1    77.2500
# 2    77.2167
# 3    77.2167
# 4    77.2000

# %%
i=result.sort_values("State")
i=i["State"].unique()
t=result[["Place Name","State"]].groupby(["State"]).count()
v=t["Place Name"]
print(type(v))
print([i.transpose()])
#pd.DataFrame(data=[i,v],columns=["State","Place Count"])
#import seaborn as sns
#sns.catplot(x=i,y=v,kind="box")
# Out:
# <class 'pandas.core.series.Series'>
# [array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Pondicherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)]

# %%
d=result[result['Province'].isna()].index
for x in d:
    result['Province'].fillna(value=result['County'][x],limit=1,inplace=True)

# %%
result.shape
# Out:
# (8255, 8)

# %% [markdown]
# ##### Function to take input from user where he wants to set up.

# %%
def get_city():
    print("Enter city : ")
    city=input()
    return city

# %% [markdown]
# ##### Function to Create a map of city passed with neighborhoods superimposed on top.

# %%
def city_map(city):
    #geolocator = Nominatim(user_agent="ny_explorer")
    #location = geolocator.geocode(city)
    #Here the latitude and longitude are hard-coded because the library doesn`t work in India, otherwise you can uncomment the above two mentioned lines
    latitude = 28.7041
    longitude = 77.1025
    map1= folium.Map(location=[latitude, longitude], zoom_start=10)
    data_city=result[result['County']==city]
    data_city= data_city.groupby('Province').agg({'Postal Code':'first','Place Name': ', '.join,'Province':'first', 'County': 'first', 'State':'first','place_name':'first','latitude':'first','longitude':'first'}).reset_index(drop=True)
    #Adding markers to the map
    venues_list=[]
    for lat,lon,place,county in zip(data_city['latitude'],data_city['longitude'],data_city['place_name'],data_city['Province']):
        label = '{}, {}'.format(place,county)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map1)
    urls=foursquare(data_city)
    for url,county in zip(urls,data_city['Province']):
        req=call(url)
        d=convert_jsontopandas(req,county)
        venues_list.append(d)
    results=convert_pandas(venues_list)
    return (map1,results,data_city)

# %% [markdown]
# ##### Function to do connect to FOURSQUARE API and get data

# %%
def four_api(lat,lon):
    CLIENT_ID = 'C3OS12MYBUFN0J1VXGD004FN3G4KIN0TFETPANW1EDWLJQE2' # your Foursquare ID
    CLIENT_SECRET = '4HOYTJLN1LEZCOLQ3Z1ISKLFRUD5IQMEQFCVLPEABNWT5T5B' # your Foursquare Secret
    VERSION = '20180604'
    LIMIT = 100 # limit of number of venues returned by Foursquare API
    radius = 500 # define radius
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat,
        lon,
        radius, 
        LIMIT)
    return url
def foursquare(data_city):
    urls=[]
    for lat,lon in zip(data_city["latitude"],data_city["longitude"]):
        url=four_api(lat,lon)
        urls.append(url)
    return urls

# %% [markdown]
# ##### Function to call url and get .json data

# %%
def call(url):
    http_proxy  = "http://GTU4KOR:Sunamya@070597@rb-proxy-apac.bosch.com:8080"
    https_proxy = "https://GTU4KOR:Sunamya@070597@rb-proxy-apac.bosch.com:8080"
    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy
                }
    r = requests.get(url, proxies=proxyDict).json()
    return r

# %% [markdown]
# ##### Function to get category

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ##### Funtion to convert .json to Pandas

# %%
def convert_jsontopandas(results,county):
    d=[]
    try:
        venues = results['response']['groups'][0]['items']
        lat=results['response']['suggestedBounds']['ne']['lat']
        lon=results['response']['suggestedBounds']['ne']['lng']
        temp=results['response']['totalResults']
        nearby_venues = json_normalize(venues) # flatten JSON
        if temp==0:
            d=[(county,lat,lon,"No venue Found",lat,lon,"No Category")]
        else:
            d=[(county,lat, lon,v['venue']['name'],v['venue']['location']['lat'],v['venue']['location']['lng'],v['venue']['categories'][0]['name']) for v in venues]
    except Exception as e:
        print("Error : ",e)
    return(d)

# %% [markdown]
# ##### Function to convert to pandas

# %%
def convert_pandas(venues_list):
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns=['County','Place Latitude','Place Longitude','Venue Name','Venue Latitude','Venue Longitude','Venue Categories']
    return nearby_venues

# %% [markdown]
# ##### Analyze Each Neighborhood and printing the neighbourhood Analysis

# %%
def analyze(v):
    print(v.groupby('County').count()) #Counting the no of categories based on County
    ny_onehot = pd.get_dummies(v[['Venue Categories']], prefix="", prefix_sep="")
    ny_onehot['Province'] = v['County'] 
    fixed_columns = [ny_onehot.columns[-1]] + list(ny_onehot.columns[:-1])
    ny_onehot = ny_onehot[fixed_columns]
    #Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
    ny_grouped = ny_onehot.groupby('Province').mean().reset_index()
    num_top_venues = 5
    for hood in ny_grouped['Province']:
        print("----"+hood+"----")
        temp = ny_grouped[ny_grouped['Province'] == hood].T.reset_index()
        temp.columns = ['Venue categories','Frequency']
        temp = temp.iloc[1:]
        temp['Frequency'] = temp['Frequency'].astype(float)
        temp = temp.round({'Frequency': 2})
        print(temp.sort_values('Frequency', ascending=False).reset_index(drop=True).head(num_top_venues))
        print('\n')
    return ny_grouped

# %% [markdown]
# ##### Let's put that into a pandas dataframe
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
def convert(ny_grouped):
    y,num_top_venues=ny_grouped.shape
    num_top_venues=num_top_venues-1
    indicators = ['st', 'nd', 'rd']

    # create columns according to number of top venues
    columns = ['Province']
    for ind in np.arange(num_top_venues):
        try:
            columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
        except:
            columns.append('{}th Most Common Venue'.format(ind+1))

    # create a new dataframe
    neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
    neighborhoods_venues_sorted['Province'] = ny_grouped['Province']
    for ind in np.arange(ny_grouped.shape[0]):
        neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(ny_grouped.iloc[ind, :], num_top_venues)
    return neighborhoods_venues_sorted

# %% [markdown]
# #### Clustering Neighbourhood

# %%
def cluster(ny_grouped,neighborhoods_venues_sorted):
    # set number of clusters
    kclusters = 3

    ny_grouped_clustering = ny_grouped.drop('Province', 1)

    # run k-means clustering
    kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(ny_grouped_clustering)

    # check cluster labels generated for each row in the dataframe
    kmeans.labels_[0:3]

    # add clustering labels
    neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

    ny_merged = data1[data1['County']==city]

    # merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
    ny_merged = ny_merged.join(neighborhoods_venues_sorted.set_index('Province'), on='Province')

    return (ny_merged,kclusters)  # check the last columns!

# %% [markdown]
# #### Creating Map to demonstrate different cluster

# %%
def maps(ny_merged,kclusters):
    latitude = 28.7041
    longitude = 77.1025
    map_clusters = folium.Map(location=[latitude, longitude], zoom_start=8)

    # set color scheme for the clusters
    x = np.arange(kclusters)
    ys = [i + x + (i*x)**2 for i in range(kclusters)]
    colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
    rainbow = [colors.rgb2hex(i) for i in colors_array]

    # add markers to the map
    markers_colors = []
    for lat, lon, poi, cluster in zip(ny_merged['latitude'], ny_merged['longitude'], ny_merged['Province'], ny_merged['Cluster Labels']):
        label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[cluster-1],
            fill=True,
            fill_color=rainbow[cluster-1],
            fill_opacity=0.7).add_to(map_clusters)

    return map_clusters

# %% [markdown]
# ##### Printing different clusters

# %%
def printcluster(ny_merged):
    y=ny_merged['Cluster Labels'].unique()
    for i in y:
        print(ny_merged.loc[ny_merged['Cluster Labels'] == i, ny_merged.columns[[1,2] + list(range(5, ny_merged.shape[1]))]])

# %% [markdown]
# ### Main body to call the program

# %%
city=get_city()
map1,v,data1=city_map(city)
ny_grouped=analyze(v)
neighborhoods_venues_sorted=convert(ny_grouped)
ny_merged,kclusters=cluster(ny_grouped,neighborhoods_venues_sorted)
map2=maps(ny_merged,kclusters)
printcluster(ny_merged)
#map1
# Out:
# Enter city :
# New Delhi
#                    Place Latitude  Place Longitude  Venue Name  \
# County
# Delhi                           4                4           4
# New Delhi                      60               60          60
# New Delhi Central               2                2           2
#
#                    Venue Latitude  Venue Longitude  Venue Categories
# County
# Delhi                           4                4                 4
# New Delhi                      60               60                60
# New Delhi Central               2                2                 2
# ----Delhi----
#         Venue categories  Frequency
# 0                    ATM       0.25
# 1         Clothing Store       0.25
# 2      Electronics Store       0.25
# 3      Food & Drink Shop       0.25
# 4  Portuguese Restaurant       0.00
#
#
# ----New Delhi----
#      Venue categories  Frequency
# 0                Café       0.12
# 1   Indian Restaurant       0.10
# 2  Chinese Restaurant       0.10
# 3                 Bar       0.08
# 4                 Pub       0.05
#
#
# ----New Delhi Central----
#           Venue categories  Frequency
# 0                  Stadium        1.0
# 1        Food & Drink Shop        0.0
# 2  South Indian Restaurant        0.0
# 3                      Pub        0.0
# 4    Portuguese Restaurant        0.0
#
#
#                                           Place Name Province place_name  \
# 0  Gopal Nagar, Arjun Park, Shyam Vihar, Najafgar...    Delhi  Najafgarh
#
#    latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 0   28.6125    76.9847               0                   ATM
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  ...  \
# 0        Clothing Store     Food & Drink Shop     Electronics Store  ...
#
#   24th Most Common Venue 25th Most Common Venue 26th Most Common Venue  \
# 0              Jazz Club                 Lounge     Miscellaneous Shop
#
#             27th Most Common Venue 28th Most Common Venue  \
# 0  Molecular Gastronomy Restaurant              Multiplex
#
#     29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 0  North Indian Restaurant                  Plaza  Portuguese Restaurant
#
#   32th Most Common Venue 33th Most Common Venue
# 0                    Pub   Fast Food Restaurant
#
# [1 rows x 39 columns]
#                                           Place Name   Province  \
# 1  New Delhi G.P.O., Parliament House, Connaught ...  New Delhi
#
#         place_name  latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 1  Connaught Place   28.6333    77.2167               2                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  ...  \
# 1    Chinese Restaurant     Indian Restaurant                   Bar  ...
#
#   24th Most Common Venue           25th Most Common Venue  \
# 1     Miscellaneous Shop  Molecular Gastronomy Restaurant
#
#   26th Most Common Venue   27th Most Common Venue 28th Most Common Venue  \
# 1              Multiplex  North Indian Restaurant                  Plaza
#
#   29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 1  Portuguese Restaurant                 Bakery                Stadium
#
#   32th Most Common Venue 33th Most Common Venue
# 1      Electronics Store                    ATM
#
# [1 rows x 39 columns]
#                                           Place Name           Province  \
# 2  Civic Centre, Darya Ganj, Minto Road, Indrapra...  New Delhi Central
#
#    place_name  latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 2  Darya Ganj   28.6333      77.25               1               Stadium
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  ...  \
# 2    Falafel Restaurant      Asian Restaurant             BBQ Joint  ...
#
#   24th Most Common Venue 25th Most Common Venue 26th Most Common Venue  \
# 2              Jazz Club                 Lounge     Miscellaneous Shop
#
#             27th Most Common Venue 28th Most Common Venue  \
# 2  Molecular Gastronomy Restaurant              Multiplex
#
#     29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 2  North Indian Restaurant                  Plaza  Portuguese Restaurant
#
#   32th Most Common Venue 33th Most Common Venue
# 2                    Pub                    ATM
#
# [1 rows x 39 columns]

# %%
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ny_merged
# Out:
#    Postal Code                                         Place Name  \
# 0       110043  Gopal Nagar, Arjun Park, Shyam Vihar, Najafgar...
# 1       110001  New Delhi G.P.O., Parliament House, Connaught ...
# 2       110002  Civic Centre, Darya Ganj, Minto Road, Indrapra...
#
#             Province     County  State       place_name  latitude  longitude  \
# 0              Delhi  New Delhi  Delhi        Najafgarh   28.6125    76.9847
# 1          New Delhi  New Delhi  Delhi  Connaught Place   28.6333    77.2167
# 2  New Delhi Central  New Delhi  Delhi       Darya Ganj   28.6333    77.2500
#
#    Cluster Labels 1st Most Common Venue  ... 24th Most Common Venue  \
# 0               0                   ATM  ...              Jazz Club
# 1               2                  Café  ...     Miscellaneous Shop
# 2               1               Stadium  ...              Jazz Club
#
#             25th Most Common Venue 26th Most Common Venue  \
# 0                           Lounge     Miscellaneous Shop
# 1  Molecular Gastronomy Restaurant              Multiplex
# 2                           Lounge     Miscellaneous Shop
#
#             27th Most Common Venue 28th Most Common Venue  \
# 0  Molecular Gastronomy Restaurant              Multiplex
# 1          North Indian Restaurant                  Plaza
# 2  Molecular Gastronomy Restaurant              Multiplex
#
#     29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 0  North Indian Restaurant                  Plaza  Portuguese Restaurant
# 1    Portuguese Restaurant                 Bakery                Stadium
# 2  North Indian Restaurant                  Plaza  Portuguese Restaurant
#
#   32th Most Common Venue 33th Most Common Venue
# 0                    Pub   Fast Food Restaurant
# 1      Electronics Store                    ATM
# 2                    Pub                    ATM
#
# [3 rows x 42 columns]

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 0, ny_merged.columns[[1,2] + list(range(5, ny_merged.shape[1]))]]
# Out:
#                                           Place Name Province place_name  \
# 0  Gopal Nagar, Arjun Park, Shyam Vihar, Najafgar...    Delhi  Najafgarh
#
#    latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 0   28.6125    76.9847               0                   ATM
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  ...  \
# 0        Clothing Store     Food & Drink Shop     Electronics Store  ...
#
#   24th Most Common Venue 25th Most Common Venue 26th Most Common Venue  \
# 0              Jazz Club                 Lounge     Miscellaneous Shop
#
#             27th Most Common Venue 28th Most Common Venue  \
# 0  Molecular Gastronomy Restaurant              Multiplex
#
#     29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 0  North Indian Restaurant                  Plaza  Portuguese Restaurant
#
#   32th Most Common Venue 33th Most Common Venue
# 0                    Pub   Fast Food Restaurant
#
# [1 rows x 39 columns]

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 1, ny_merged.columns[[1,2] + list(range(5, ny_merged.shape[1]))]]
# Out:
#                                           Place Name           Province  \
# 2  Civic Centre, Darya Ganj, Minto Road, Indrapra...  New Delhi Central
#
#    place_name  latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 2  Darya Ganj   28.6333      77.25               1               Stadium
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  ...  \
# 2    Falafel Restaurant      Asian Restaurant             BBQ Joint  ...
#
#   24th Most Common Venue 25th Most Common Venue 26th Most Common Venue  \
# 2              Jazz Club                 Lounge     Miscellaneous Shop
#
#             27th Most Common Venue 28th Most Common Venue  \
# 2  Molecular Gastronomy Restaurant              Multiplex
#
#     29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 2  North Indian Restaurant                  Plaza  Portuguese Restaurant
#
#   32th Most Common Venue 33th Most Common Venue
# 2                    Pub                    ATM
#
# [1 rows x 39 columns]

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 2, ny_merged.columns[[1,2] + list(range(5, ny_merged.shape[1]))]]
# Out:
#                                           Place Name   Province  \
# 1  New Delhi G.P.O., Parliament House, Connaught ...  New Delhi
#
#         place_name  latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 1  Connaught Place   28.6333    77.2167               2                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  ...  \
# 1    Chinese Restaurant     Indian Restaurant                   Bar  ...
#
#   24th Most Common Venue           25th Most Common Venue  \
# 1     Miscellaneous Shop  Molecular Gastronomy Restaurant
#
#   26th Most Common Venue   27th Most Common Venue 28th Most Common Venue  \
# 1              Multiplex  North Indian Restaurant                  Plaza
#
#   29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 1  Portuguese Restaurant                 Bakery                Stadium
#
#   32th Most Common Venue 33th Most Common Venue
# 1      Electronics Store                    ATM
#
# [1 rows x 39 columns]

# %%
neighborhoods_venues_sorted
# Out:
#    Cluster Labels           Province 1st Most Common Venue  \
# 0               0              Delhi                   ATM
# 1               2          New Delhi                  Café
# 2               1  New Delhi Central               Stadium
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0        Clothing Store     Food & Drink Shop     Electronics Store
# 1    Chinese Restaurant     Indian Restaurant                   Bar
# 2    Falafel Restaurant      Asian Restaurant             BBQ Joint
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                Bakery                   Bar                Bistro
# 1  Fast Food Restaurant                   Pub           Coffee Shop
# 2                Bakery                   Bar                Bistro
#
#   8th Most Common Venue  ... 24th Most Common Venue  \
# 0                  Café  ...              Jazz Club
# 1                Lounge  ...     Miscellaneous Shop
# 2                  Café  ...              Jazz Club
#
#             25th Most Common Venue 26th Most Common Venue  \
# 0                           Lounge     Miscellaneous Shop
# 1  Molecular Gastronomy Restaurant              Multiplex
# 2                           Lounge     Miscellaneous Shop
#
#             27th Most Common Venue 28th Most Common Venue  \
# 0  Molecular Gastronomy Restaurant              Multiplex
# 1          North Indian Restaurant                  Plaza
# 2  Molecular Gastronomy Restaurant              Multiplex
#
#     29th Most Common Venue 30th Most Common Venue 31th Most Common Venue  \
# 0  North Indian Restaurant                  Plaza  Portuguese Restaurant
# 1    Portuguese Restaurant                 Bakery                Stadium
# 2  North Indian Restaurant                  Plaza  Portuguese Restaurant
#
#   32th Most Common Venue 33th Most Common Venue
# 0                    Pub   Fast Food Restaurant
# 1      Electronics Store                    ATM
# 2                    Pub                    ATM
#
# [3 rows x 35 columns]
